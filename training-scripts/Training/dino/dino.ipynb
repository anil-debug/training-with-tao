# %% [markdown]
# # Object Detection using TAO DINO
#
# Transfer learning is the process of transferring learned features from one application to another. It is a commonly used training technique where you use a model trained on one task and re-train to use it on a different task.
#
# Train Adapt Optimize (TAO) Toolkit  is a simple and easy-to-use Python based AI toolkit for taking purpose-built AI models and customizing them with users' own data.
#
# <img align="center" src="https://developer.nvidia.com/sites/default/files/akamai/TAO/tlt-tao-toolkit-bring-your-own-model-diagram.png" width="1080">
#
# ## What is DINO?
#
# [DINO](https://arxiv.org/abs/2203.03605) is a state of the art transformer-based object detection model. Similar to Deformable DETR, DINO does not use heuristics based methods like NMS or IOU assignment found in convolution-based object detection models like Faster RCNN. Compared to Deformable DETR, DINO uses de-noising during training which can help training to converge faster.
#
# In TAO, three different types of backbone networks are supported: [ResNet50](https://arxiv.org/abs/1512.03385), [GCViT](https://arxiv.org/abs/2206.09959), and [FAN](https://arxiv.org/abs/2204.12451). In this notebook, we use the most advanced network called FAN which is also a transformer-based classification network. For more details about training FAN backbones, please refer to the classification pytorch notebook.
#
# ### Sample prediction of FAN-Tiny + DINO model
# <img align="center" src="sample.jpg" width="960">

# %% [markdown]
# ## Learning Objectives
#
# In this notebook, you will learn how to leverage the simplicity and convenience of TAO to:
#
# * Take a pretrained model and train an DINO model on COCO dataset
# * Evaluate the trained model
# * Run inference with the trained model and visualize the result
# * Export the trained model to a .onnx file for deployment to DeepStream
# * Generate TensorRT engine using tao-deploy and verify the engine through evaluation
#
# At the end of this notebook, you will have generated a trained `dino` model
# which you may deploy via [DeepStream](https://developer.nvidia.com/deepstream-sdk).
#
# ## Table of Contents
#
# This notebook shows an example usecase of DINO using Train Adapt Optimize (TAO) Toolkit.
#
# 0. [Set up env variables and map drives](#head-0)
# 1. [Installing the TAO launcher](#head-1)
# 2. [Prepare dataset and pre-trained model](#head-2)
# 3. [Provide training specification](#head-3)
# 4. [Run TAO training](#head-4)
# 5. [Evaluate a trained model](#head-5)
# 6. [Visualize inferences](#head-6)
# 7. [Deploy](#head-7)

# %% [markdown]
# ## 0. Set up env variables and map drives <a class="anchor" id="head-0"></a>
#
# The following notebook requires the user to set an env variable called the `$LOCAL_PROJECT_DIR` as the path to the users workspace. Please note that the dataset to run this notebook is expected to reside in the `$LOCAL_PROJECT_DIR/data`, while the TAO experiment generated collaterals will be output to `$LOCAL_PROJECT_DIR/dino/results`. More information on how to set up the dataset and the supported steps in the TAO workflow are provided in the subsequent cells.
#
# The TAO launcher uses docker containers under the hood, and **for our data and results directory to be visible to the docker, they need to be mapped**. The launcher can be configured using the config file `~/.tao_mounts.json`. Apart from the mounts, you can also configure additional options like the Environment Variables and amount of Shared Memory available to the TAO launcher. <br>
#
# `IMPORTANT NOTE:` The code below creates a sample `~/.tao_mounts.json`  file. Here, we can map directories in which we save the data, specs, results and cache. You should configure it for your specific case so these directories are correctly visible to the docker container.

# %%
import os

# Please define this local project directory that needs to be mapped to the TAO docker session.
# %env LOCAL_PROJECT_DIR=/home/solomon/tao-experiments

os.environ["HOST_DATA_DIR"] = os.path.join(os.getenv("LOCAL_PROJECT_DIR", os.getcwd()), "data")
os.environ["HOST_RESULTS_DIR"] = os.path.join(os.getenv("LOCAL_PROJECT_DIR", os.getcwd()), "dino", "results")

# Set this path if you don't run the notebook from the samples directory.
# %env NOTEBOOK_ROOT=~/tao-samples/dino

# The sample spec files are present in the same path as the downloaded samples.
os.environ["HOST_SPECS_DIR"] = os.path.join(
    os.getenv("NOTEBOOK_ROOT", os.getcwd()),
    "specs"
)
# Out:
# env: LOCAL_PROJECT_DIR=/home/solomon/tao-experiments

# %%
! mkdir -p $HOST_DATA_DIR
! mkdir -p $HOST_SPECS_DIR
! mkdir -p $HOST_RESULTS_DIR

# %%
# Mapping up the local directories to the TAO docker.
import json
import os
mounts_file = os.path.expanduser("~/.tao_mounts.json")
tao_configs = {
   "Mounts":[
         # Mapping the Local project directory
        {
            "source": os.environ["LOCAL_PROJECT_DIR"],
            "destination": "/workspace/tao-experiments"
        },
       {
           "source": os.environ["HOST_DATA_DIR"],
           "destination": "/data"
       },
       {
           "source": os.environ["HOST_SPECS_DIR"],
           "destination": "/specs"
       },
       {
           "source": os.environ["HOST_RESULTS_DIR"],
           "destination": "/results"
       }
   ],
   "DockerOptions": {
        "shm_size": "16G",
        "ulimits": {
            "memlock": -1,
            "stack": 67108864
         },
        "user": "{}:{}".format(os.getuid(), os.getgid()),
        "network": "host"
   }
}
# Writing the mounts file.
with open(mounts_file, "w") as mfile:
    json.dump(tao_configs, mfile, indent=4)

# %%
# !cat ~/.tao_mounts.json
# Out:
# {
#     "Mounts": [
#         {
#             "source": "/home/solomon/tao-experiments",
#             "destination": "/workspace/tao-experiments"
#         },
#         {
#             "source": "/home/solomon/tao-experiments/data",
#             "destination": "/data"
#         },
#         {
#             "source": "/home/solomon/tao-getting-started_5.0.0/notebooks/tao_launcher_starter_kit/dino/specs",
#             "destination": "/specs"
#         },
#         {
#             "source": "/home/solomon/tao-experiments/dino/results",
#             "destination": "/results"
#         }
#     ],
#     "DockerOptions": {
#         "shm_size": "16G",
#         "ulimits": {
#             "memlock": -1,
#             "stack": 67108864
#         },
#         "user": "1000:1000",
#         "network": "host"
#     }
# }

# %% [markdown]
# ## 1. Installing the TAO launcher <a class="anchor" id="head-1"></a>
# The TAO launcher is a python package distributed as a python wheel listed in the `nvidia-pyindex` python index. You may install the launcher by executing the following cell.
#
# Please note that TAO Toolkit recommends users to run the TAO launcher in a virtual env with python 3.6.9. You may follow the instruction in this [page](https://virtualenvwrapper.readthedocs.io/en/latest/install.html) to set up a python virtual env using the `virtualenv` and `virtualenvwrapper` packages. Once you have setup virtualenvwrapper, please set the version of python to be used in the virtual env by using the `VIRTUALENVWRAPPER_PYTHON` variable. You may do so by running
#
# ```sh
# export VIRTUALENVWRAPPER_PYTHON=/path/to/bin/python3.x
# ```
# where x >= 6 and <= 8
#
# We recommend performing this step first and then launching the notebook from the virtual environment. In addition to installing TAO python package, please make sure of the following software requirements:
# * python >=3.6.9 < 3.8.x
# * docker-ce > 19.03.5
# * docker-API 1.40
# * nvidia-container-toolkit > 1.3.0-1
# * nvidia-container-runtime > 3.4.0-1
# * nvidia-docker2 > 2.5.0-1
# * nvidia-driver > 455+
#
# Once you have installed the pre-requisites, please log in to the docker registry nvcr.io by following the command below
#
# ```sh
# docker login nvcr.io
# ```
#
# You will be triggered to enter a username and password. The username is `$oauthtoken` and the password is the API key generated from `ngc.nvidia.com`. Please follow the instructions in the [NGC setup guide](https://docs.nvidia.com/ngc/ngc-overview/index.html#generating-api-key) to generate your own API key.
#
# Please note that TAO Toolkit recommends users to run the TAO launcher in a virtual env with python >=3.6.9. You may follow the instruction in this [page](https://virtualenvwrapper.readthedocs.io/en/latest/install.html) to set up a python virtual env using the virtualenv and virtualenvwrapper packages.

# %%
# SKIP this step IF you have already installed the TAO launcher.
# !pip3 install nvidia-pyindex
# !pip3 install nvidia-tao
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: nvidia-pyindex in /home/solomon/.local/lib/python3.8/site-packages (1.0.9)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: nvidia-tao in /home/solomon/.local/lib/python3.8/site-packages (5.0.0)
# Requirement already satisfied: certifi>=2022.12.07 in /home/solomon/.local/lib/python3.8/site-packages (from nvidia-tao) (2023.7.22)
# Requirement already satisfied: idna==2.10 in /home/solomon/.local/lib/python3.8/site-packages (from nvidia-tao) (2.10)
# Requirement already satisfied: requests>=2.31.0 in /home/solomon/.local/lib/python3.8/site-packages (from nvidia-tao) (2.31.0)
# Requirement already satisfied: chardet==3.0.4 in /home/solomon/.local/lib/python3.8/site-packages (from nvidia-tao) (3.0.4)
# Requirement already satisfied: six==1.15.0 in /home/solomon/.local/lib/python3.8/site-packages (from nvidia-tao) (1.15.0)
# Requirement already satisfied: websocket-client==0.57.0 in /home/solomon/.local/lib/python3.8/site-packages (from nvidia-tao) (0.57.0)
# Requirement already satisfied: docker-pycreds==0.4.0 in /home/solomon/.local/lib/python3.8/site-packages (from nvidia-tao) (0.4.0)
# Requirement already satisfied: tabulate==0.8.7 in /home/solomon/.local/lib/python3.8/site-packages (from nvidia-tao) (0.8.7)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.15 in /home/solomon/.local/lib/python3.8/site-packages (from nvidia-tao) (1.26.16)
# Requirement already satisfied: docker==4.3.1 in /home/solomon/.local/lib/python3.8/site-packages (from nvidia-tao) (4.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/solomon/.local/lib/python3.8/site-packages (from requests>=2.31.0->nvidia-tao) (3.2.0)

# %%
# View the versions of the TAO launcher
# !tao info
# Out:
# Configuration of the TAO Toolkit Instance
# task_group: ['model', 'dataset', 'deploy']
# format_version: 3.0
# toolkit_version: 5.0.0
# published_date: 07/14/2023

# %% [markdown]
# ## 2. Prepare dataset and pre-trained model <a class="anchor" id="head-2"></a>

# %% [markdown]
# ### 2.1 Prepare dataset

# %% [markdown]
#  We will be using the COCO dataset for the tutorial. The following script will download COCO dataset automatically.

# %%
# # Create local dir
# !mkdir -p $HOST_DATA_DIR
# # Download the data
# !bash $HOST_SPECS_DIR/download_coco.sh $HOST_DATA_DIR

# %%
# Verification
# !ls -l $HOST_DATA_DIR/raw-data
# Out:
# total 12
# drwxrwxr-x 2 solomon solomon 4096  七  28 13:47 annotations
# drwxrwxr-x 2 solomon solomon 4096  七  28 13:35 train2017
# drwxrwxr-x 2 solomon solomon 4096  七  28 13:36 val2017

# %% [markdown]
# ### 2.2 Download pre-trained model

# %% [markdown]
# We will use NGC CLI to get the pre-trained models. For more details, go to [ngc.nvidia.com](ngc.nvidia.com) and click the SETUP on the navigation bar.

# %%
# Installing NGC CLI on the local machine.
## Download and install
# %env CLI=ngccli_cat_linux.zip
# !mkdir -p $LOCAL_PROJECT_DIR/ngccli

# Remove any previously existing CLI installations
# !rm -rf $LOCAL_PROJECT_DIR/ngccli/*
# !wget "https://ngc.nvidia.com/downloads/$CLI" -P $LOCAL_PROJECT_DIR/ngccli
# !unzip -u "$LOCAL_PROJECT_DIR/ngccli/$CLI" -d $LOCAL_PROJECT_DIR/ngccli/
# !rm $LOCAL_PROJECT_DIR/ngccli/*.zip 
os.environ["PATH"]="{}/ngccli/ngc-cli:{}".format(os.getenv("LOCAL_PROJECT_DIR", ""), os.getenv("PATH", ""))
# Out:
# env: CLI=ngccli_cat_linux.zip
# --2023-07-28 15:13:13--  https://ngc.nvidia.com/downloads/ngccli_cat_linux.zip
# Resolving ngc.nvidia.com (ngc.nvidia.com)... 18.155.68.90, 18.155.68.60, 18.155.68.65, ...
# Connecting to ngc.nvidia.com (ngc.nvidia.com)|18.155.68.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45656890 (44M) [application/zip]
# Saving to: ‘/home/solomon/tao-experiments/ngccli/ngccli_cat_linux.zip’
#
# ngccli_cat_linux.zi 100%[===================>]  43.54M  10.7MB/s    in 5.3s
#
# 2023-07-28 15:13:20 (8.21 MB/s) - ‘/home/solomon/tao-experiments/ngccli/ngccli_cat_linux.zip’ saved [45656890/45656890]
#
# Archive:  /home/solomon/tao-experiments/ngccli/ngccli_cat_linux.zip
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/examples/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/examples/s3.rst
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/examples/cloudfront.rst
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/dynamodb/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/dynamodb/2012-08-10/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/dynamodb/2012-08-10/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/sqs/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/sqs/2012-11-05/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/sqs/2012-11-05/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/opsworks/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/opsworks/2013-02-18/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/opsworks/2013-02-18/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/iam/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/iam/2010-05-08/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/iam/2010-05-08/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/2014-10-01/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/2014-10-01/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/2015-10-01/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/2015-10-01/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/2015-03-01/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/2015-03-01/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/2016-09-15/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/2016-09-15/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/2016-04-01/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/2016-04-01/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/2015-04-15/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/2015-04-15/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/2016-11-15/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/ec2/2016-11-15/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/s3/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/s3/2006-03-01/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/s3/2006-03-01/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/sns/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/sns/2010-03-31/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/sns/2010-03-31/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/cloudformation/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/cloudformation/2010-05-15/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/cloudformation/2010-05-15/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/cloudwatch/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/cloudwatch/2010-08-01/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/cloudwatch/2010-08-01/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/glacier/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/glacier/2012-06-01/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/boto3/data/glacier/2012-06-01/resources-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/wrapt-1.12.1.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/wrapt-1.12.1.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/wrapt-1.12.1.dist-info/LICENSE
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/wrapt-1.12.1.dist-info/METADATA
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/wrapt-1.12.1.dist-info/WHEEL
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/wrapt-1.12.1.dist-info/INSTALLER
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/wrapt-1.12.1.dist-info/top_level.txt
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/pycares/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/pycares/_cares.cpython-39-x86_64-linux-gnu.so
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/attrs-23.1.0.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/attrs-23.1.0.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/attrs-23.1.0.dist-info/METADATA
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/attrs-23.1.0.dist-info/WHEEL
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/attrs-23.1.0.dist-info/licenses/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/attrs-23.1.0.dist-info/licenses/LICENSE
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/attrs-23.1.0.dist-info/INSTALLER
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/grpc/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/grpc/_cython/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/grpc/_cython/_credentials/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/grpc/_cython/_credentials/roots.pem
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/grpc/_cython/cygrpc.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/libcrypto.so.10
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_sdk-1.19.0.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_sdk-1.19.0.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_sdk-1.19.0.dist-info/entry_points.txt
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_sdk-1.19.0.dist-info/METADATA
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_sdk-1.19.0.dist-info/WHEEL
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_sdk-1.19.0.dist-info/licenses/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_sdk-1.19.0.dist-info/licenses/LICENSE
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_sdk-1.19.0.dist-info/INSTALLER
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/main.so
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography-39.0.2.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography-39.0.2.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography-39.0.2.dist-info/LICENSE.BSD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography-39.0.2.dist-info/LICENSE
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography-39.0.2.dist-info/LICENSE.PSF
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography-39.0.2.dist-info/METADATA
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography-39.0.2.dist-info/LICENSE.APACHE
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography-39.0.2.dist-info/WHEEL
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography-39.0.2.dist-info/INSTALLER
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography-39.0.2.dist-info/top_level.txt
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/libkrb5support.so.0
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/wrapt/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/wrapt/_wrappers.cpython-39-x86_64-linux-gnu.so
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/googleapis_common_protos-1.59.1.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/googleapis_common_protos-1.59.1.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/googleapis_common_protos-1.59.1.dist-info/LICENSE
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/googleapis_common_protos-1.59.1.dist-info/METADATA
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/googleapis_common_protos-1.59.1.dist-info/namespace_packages.txt
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/googleapis_common_protos-1.59.1.dist-info/WHEEL
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/googleapis_common_protos-1.59.1.dist-info/INSTALLER
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/googleapis_common_protos-1.59.1.dist-info/top_level.txt
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/libcom_err.so.2
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography/hazmat/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography/hazmat/bindings/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography/hazmat/bindings/_openssl.abi3.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/cryptography/hazmat/bindings/_rust.abi3.so
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/backoff-2.2.1.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/backoff-2.2.1.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/backoff-2.2.1.dist-info/LICENSE
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/backoff-2.2.1.dist-info/METADATA
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/backoff-2.2.1.dist-info/WHEEL
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/backoff-2.2.1.dist-info/INSTALLER
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/libpcre.so.1
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/libgssapi_krb5.so.2
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/libgcc_s.so.1
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/context/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/context/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/context/context.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/context/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/context/__pycache__/context.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/context/__pycache__/__init__.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/context/contextvars_context.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/distro.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/utils.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/environment_variables.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/instrumentor.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/auto_instrumentation/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/auto_instrumentation/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/auto_instrumentation/sitecustomize.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/bootstrap_gen.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/version.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/sqlcommenter_utils.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/bootstrap.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/propagators.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/dependencies.py
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/instrumentation/py.typed
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/util/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/util/re.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/util/_importlib_metadata.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/util/types.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/util/_once.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/util/_providers.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/util/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/util/__pycache__/re.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/util/__pycache__/_once.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/util/__pycache__/types.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/util/__pycache__/_importlib_metadata.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/util/__pycache__/_providers.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/environment_variables.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/attributes/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/attributes/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/attributes/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/attributes/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/resource/
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/resource/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/resource/v1/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/resource/v1/resource_pb2.pyi
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/resource/v1/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/resource/v1/resource_pb2.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/resource/v1/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/resource/v1/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/resource/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/resource/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/logs/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/logs/v1/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/logs/v1/logs_pb2.pyi
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/logs/v1/logs_pb2.py
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/logs/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/logs/v1/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/logs/v1/logs_service_pb2.pyi
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/logs/v1/logs_service_pb2.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/logs/v1/logs_service_pb2_grpc.py
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/metrics/
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/metrics/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/metrics/v1/
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/metrics/v1/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/metrics/v1/metrics_service_pb2.pyi
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/metrics/v1/metrics_service_pb2.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/metrics/v1/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/metrics/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/metrics/v1/metrics_service_pb2_grpc.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/metrics/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/metrics/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/trace/
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/trace/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/trace/v1/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/trace/v1/trace_service_pb2.pyi
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/trace/v1/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/trace/v1/trace_service_pb2_grpc.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/trace/v1/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/trace/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/trace/v1/trace_service_pb2.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/trace/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/trace/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/collector/__pycache__/__init__.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/version.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/metrics/
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/metrics/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/metrics/v1/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/metrics/v1/metrics_pb2.pyi
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/metrics/v1/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/metrics/v1/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/metrics/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/metrics/v1/metrics_pb2.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/metrics/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/metrics/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/trace/
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/trace/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/trace/v1/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/trace/v1/trace_pb2.pyi
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/trace/v1/trace_pb2.py
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/trace/v1/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/trace/v1/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/trace/v1/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/trace/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/trace/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/common/
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/common/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/common/v1/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/common/v1/common_pb2.py
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/common/v1/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/common/v1/common_pb2.pyi
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/common/v1/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/common/v1/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/common/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/proto/common/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/propagators/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/propagators/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/propagators/__pycache__/composite.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/propagators/__pycache__/textmap.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/propagators/composite.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/propagators/textmap.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/version.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/trace_exporter/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/trace_exporter/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/version.py
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/py.typed
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/metric_exporter/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/metric_exporter/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/exporter.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/_log_exporter/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/_log_exporter/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/trace_encoder/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/trace_encoder/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/metrics_encoder/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/metrics_encoder/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/_log_encoder/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/_log_encoder/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/version.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/trace_encoder.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/_log_encoder.py
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/py.typed
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/exporter/otlp/proto/common/metrics_encoder.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/resource/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/resource/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/resource/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/resource/__pycache__/__init__.cpython-39.pyc
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/version.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/metrics/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/metrics/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/metrics/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/metrics/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/trace/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/trace/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/trace/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/trace/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/semconv/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/baggage/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/baggage/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/baggage/propagation/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/baggage/propagation/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/baggage/propagation/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/baggage/propagation/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/baggage/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/baggage/__pycache__/__init__.cpython-39.pyc
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/py.typed
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/propagate/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/propagate/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/propagate/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/propagate/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/metrics/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/metrics/_internal/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/metrics/_internal/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/metrics/_internal/instrument.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/metrics/_internal/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/metrics/_internal/__pycache__/observation.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/metrics/_internal/__pycache__/__init__.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/metrics/_internal/__pycache__/instrument.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/metrics/_internal/observation.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/metrics/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/metrics/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/metrics/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/trace/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/trace/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/trace/propagation/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/trace/propagation/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/trace/propagation/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/trace/propagation/__pycache__/__init__.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/trace/propagation/__pycache__/tracecontext.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/trace/propagation/tracecontext.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/trace/status.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/trace/span.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/trace/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/trace/__pycache__/__init__.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/trace/__pycache__/span.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/trace/__pycache__/status.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/__pycache__/environment_variables.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/__init__.pyi
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/util/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/util/__init__.pyi
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/util/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/util/instrumentation.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/environment_variables.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/_configuration/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/_configuration/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/version.py
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/py.typed
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/point.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/sdk_configuration.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/ieee_754.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/logarithm_mapping.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/exponent_mapping.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/errors.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/ieee_754.md
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/buckets.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/exceptions.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/measurement_consumer.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/export/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/export/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/metric_reader_storage.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/_view_instrument_match.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/aggregation.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/view.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/instrument.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/_internal/measurement.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/export/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/export/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/view/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/metrics/view/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/trace/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/trace/export/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/trace/export/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/trace/export/in_memory_span_exporter.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/trace/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/trace/id_generator.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/trace/sampling.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/resources/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/resources/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/error_handler/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/error_handler/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/_logs/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/_logs/_internal/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/_logs/_internal/export/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/_logs/_internal/export/in_memory_log_exporter.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/_logs/_internal/export/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/_logs/_internal/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/_logs/export/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/_logs/export/__init__.py
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/sdk/_logs/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/_logs/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/_logs/_internal/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/_logs/_internal/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/_logs/_internal/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/_logs/_internal/__pycache__/__init__.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/_logs/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/_logs/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/_logs/__pycache__/__init__.cpython-39.pyc
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/_logs/severity/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/_logs/severity/__init__.py
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/_logs/severity/__pycache__/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry/_logs/severity/__pycache__/__init__.cpython-39.pyc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/libpython3.9.so.1.0
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/certifi/
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/certifi/py.typed
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/certifi/cacert.pem
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/frozenlist/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/frozenlist/_frozenlist.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/libfreebl3.so
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/grpcio-1.56.0.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/grpcio-1.56.0.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/grpcio-1.56.0.dist-info/LICENSE
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/grpcio-1.56.0.dist-info/METADATA
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/grpcio-1.56.0.dist-info/WHEEL
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/grpcio-1.56.0.dist-info/INSTALLER
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/grpcio-1.56.0.dist-info/top_level.txt
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/multidict/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/multidict/_multidict.cpython-39-x86_64-linux-gnu.so
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_api-1.19.0.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_api-1.19.0.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_api-1.19.0.dist-info/entry_points.txt
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_api-1.19.0.dist-info/METADATA
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_api-1.19.0.dist-info/WHEEL
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_api-1.19.0.dist-info/licenses/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_api-1.19.0.dist-info/licenses/LICENSE
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_api-1.19.0.dist-info/INSTALLER
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/libkrb5.so.3
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/yarl/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/yarl/_quoting_c.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/ngc
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/libstdc++.so.6
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/importlib_metadata-6.8.0.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/importlib_metadata-6.8.0.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/importlib_metadata-6.8.0.dist-info/LICENSE
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/importlib_metadata-6.8.0.dist-info/METADATA
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/importlib_metadata-6.8.0.dist-info/WHEEL
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/importlib_metadata-6.8.0.dist-info/INSTALLER
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/importlib_metadata-6.8.0.dist-info/top_level.txt
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/libk5crypto.so.3
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_codecs_tw.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/termios.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_decimal.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_datetime.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/grp.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_bisect.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_elementtree.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_sha512.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/fcntl.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_codecs_iso2022.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_multibytecodec.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/binascii.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_csv.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_posixsubprocess.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_sha256.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_codecs_hk.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_multiprocessing.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/select.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_asyncio.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/unicodedata.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_codecs_kr.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_ctypes.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_posixshmem.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/array.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_blake2.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/resource.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/lib-dynload/_ssl.cpython-39-x86_64-linux-gnu.so
# ...
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-09-07/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-09-07/service-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-09-07/examples-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2018-06-18/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2018-06-18/waiters-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2018-06-18/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2018-06-18/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2018-06-18/service-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2018-06-18/examples-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2018-11-05/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2018-11-05/waiters-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2018-11-05/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2018-11-05/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2018-11-05/service-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2018-11-05/examples-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-01-28/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-01-28/waiters-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-01-28/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-01-28/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-01-28/service-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-01-28/examples-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2019-03-26/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2019-03-26/waiters-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2019-03-26/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2019-03-26/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2019-03-26/service-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2019-03-26/examples-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2015-09-17/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2015-09-17/waiters-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2015-09-17/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2015-09-17/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2015-09-17/service-2.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2014-11-06/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2014-11-06/waiters-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2014-11-06/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2014-11-06/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2014-11-06/service-2.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-11-25/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-11-25/waiters-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-11-25/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-11-25/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-11-25/service-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2016-11-25/examples-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2015-07-27/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2015-07-27/waiters-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2015-07-27/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2015-07-27/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/cloudfront/2015-07-27/service-2.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/mgn/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/mgn/2020-02-26/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/mgn/2020-02-26/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/mgn/2020-02-26/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/mgn/2020-02-26/service-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/mgn/2020-02-26/examples-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/codestar/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/codestar/2017-04-19/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/codestar/2017-04-19/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/codestar/2017-04-19/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/codestar/2017-04-19/service-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/codestar/2017-04-19/examples-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/imagebuilder/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/imagebuilder/2019-12-02/
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/imagebuilder/2019-12-02/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/imagebuilder/2019-12-02/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/imagebuilder/2019-12-02/service-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/imagebuilder/2019-12-02/examples-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/timestream-write/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/timestream-write/2018-11-01/
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/timestream-write/2018-11-01/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/timestream-write/2018-11-01/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/timestream-write/2018-11-01/service-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/timestream-write/2018-11-01/examples-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/arc-zonal-shift/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/arc-zonal-shift/2022-10-30/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/arc-zonal-shift/2022-10-30/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/arc-zonal-shift/2022-10-30/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/arc-zonal-shift/2022-10-30/service-2.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/rekognition/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/rekognition/2016-06-27/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/rekognition/2016-06-27/waiters-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/rekognition/2016-06-27/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/rekognition/2016-06-27/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/rekognition/2016-06-27/service-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/rekognition/2016-06-27/examples-1.json
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/braket/
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/braket/2019-09-01/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/braket/2019-09-01/paginators-1.json
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/braket/2019-09-01/endpoint-rule-set-1.json.gz
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/braket/2019-09-01/service-2.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/data/braket/2019-09-01/examples-1.json
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/botocore/cacert.pem
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/prettytable-2.0.0.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/prettytable-2.0.0.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/prettytable-2.0.0.dist-info/COPYING
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/prettytable-2.0.0.dist-info/METADATA
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/prettytable-2.0.0.dist-info/WHEEL
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/prettytable-2.0.0.dist-info/INSTALLER
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/prettytable-2.0.0.dist-info/top_level.txt
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.19.0.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.19.0.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.19.0.dist-info/METADATA
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.19.0.dist-info/WHEEL
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.19.0.dist-info/licenses/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.19.0.dist-info/licenses/LICENSE
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.19.0.dist-info/INSTALLER
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/aiohttp/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/aiohttp/_http_writer.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/aiohttp/_http_parser.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/aiohttp/_helpers.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/aiohttp/_websocket.cpython-39-x86_64-linux-gnu.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/libkeyutils.so.1
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/_cffi_backend.cpython-39-x86_64-linux-gnu.so
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/psutil/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/psutil/_psutil_linux.abi3.so
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/psutil/_psutil_posix.abi3.so
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/protobuf-3.19.5.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/protobuf-3.19.5.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/protobuf-3.19.5.dist-info/METADATA
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/protobuf-3.19.5.dist-info/namespace_packages.txt
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/protobuf-3.19.5.dist-info/WHEEL
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/protobuf-3.19.5.dist-info/INSTALLER
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/protobuf-3.19.5.dist-info/top_level.txt
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/libffi.so.6
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/setuptools-49.6.0.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/setuptools-49.6.0.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/setuptools-49.6.0.dist-info/entry_points.txt
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/setuptools-49.6.0.dist-info/LICENSE
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/setuptools-49.6.0.dist-info/dependency_links.txt
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/setuptools-49.6.0.dist-info/METADATA
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/setuptools-49.6.0.dist-info/WHEEL
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/setuptools-49.6.0.dist-info/zip-safe
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/setuptools-49.6.0.dist-info/INSTALLER
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/setuptools-49.6.0.dist-info/top_level.txt
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/markupsafe/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/markupsafe/_speedups.cpython-39-x86_64-linux-gnu.so
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_instrumentation-0.38b0.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_instrumentation-0.38b0.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_instrumentation-0.38b0.dist-info/entry_points.txt
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_instrumentation-0.38b0.dist-info/METADATA
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_instrumentation-0.38b0.dist-info/WHEEL
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_instrumentation-0.38b0.dist-info/licenses/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_instrumentation-0.38b0.dist-info/licenses/LICENSE
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/opentelemetry_instrumentation-0.38b0.dist-info/INSTALLER
#    creating: /home/solomon/tao-experiments/ngccli/ngc-cli/Deprecated-1.2.14.dist-info/
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/Deprecated-1.2.14.dist-info/RECORD
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/Deprecated-1.2.14.dist-info/METADATA
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/Deprecated-1.2.14.dist-info/LICENSE.rst
#   inflating: /home/solomon/tao-experiments/ngccli/ngc-cli/Deprecated-1.2.14.dist-info/WHEEL
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/Deprecated-1.2.14.dist-info/INSTALLER
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli/Deprecated-1.2.14.dist-info/top_level.txt
#  extracting: /home/solomon/tao-experiments/ngccli/ngc-cli.md5

# %%
# !ngc registry model list nvidia/tao/pretrained_dino_nvimagenet:*
# Out:
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+
# | Versi | Accur | Epoch | Batch | GPU   | Memor | File  | Statu | Creat |
# | on    | acy   | s     | Size  | Model | y Foo | Size  | s     | ed    |
# |       |       |       |       |       | tprin |       |       | Date  |
# |       |       |       |       |       | t     |       |       |       |
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+
# | resne |       |       | 1     | V100  | 292.9 | 292.8 | UPLOA | Jul   |
# | t50   |       |       |       |       |       | 9 MB  | D_COM | 17,   |
# |       |       |       |       |       |       |       | PLETE | 2023  |
# | gcvit |       |       | 1     | V100  | 47.7  | 47.7  | UPLOA | Jul   |
# | _xxti |       |       |       |       |       | MB    | D_COM | 17,   |
# | ny_nv |       |       |       |       |       |       | PLETE | 2023  |
# | image |       |       |       |       |       |       |       |       |
# | net   |       |       |       |       |       |       |       |       |
# | gcvit |       |       | 1     | V100  | 78.3  | 78.3  | UPLOA | Jul   |
# | _xtin |       |       |       |       |       | MB    | D_COM | 17,   |
# | y_nvi |       |       |       |       |       |       | PLETE | 2023  |
# | magen |       |       |       |       |       |       |       |       |
# | et    |       |       |       |       |       |       |       |       |
# | gcvit |       |       | 1     | V100  | 113.6 | 113.6 | UPLOA | Jul   |
# | _tiny |       |       |       |       |       | 1 MB  | D_COM | 17,   |
# | _nvim |       |       |       |       |       |       | PLETE | 2023  |
# | agene |       |       |       |       |       |       |       |       |
# | t     |       |       |       |       |       |       |       |       |
# | gcvit |       |       | 1     | V100  | 200.9 | 200.8 | UPLOA | Jul   |
# | _smal |       |       |       |       |       | 7 MB  | D_COM | 17,   |
# | l_nvi |       |       |       |       |       |       | PLETE | 2023  |
# | magen |       |       |       |       |       |       |       |       |
# | et    |       |       |       |       |       |       |       |       |
# | gcvit |       |       | 1     | V100  | 350.5 | 350.5 | UPLOA | Jul   |
# | _base |       |       |       |       |       | 1 MB  | D_COM | 17,   |
# | _nvim |       |       |       |       |       |       | PLETE | 2023  |
# | agene |       |       |       |       |       |       |       |       |
# | t     |       |       |       |       |       |       |       |       |
# | fan_s |       |       | 1     | V100  | 99.9  | 99.88 | UPLOA | Jul   |
# | mall_ |       |       |       |       |       | MB    | D_COM | 17,   |
# | hybri |       |       |       |       |       |       | PLETE | 2023  |
# | d_nvi |       |       |       |       |       |       |       |       |
# | magen |       |       |       |       |       |       |       |       |
# | et    |       |       |       |       |       |       |       |       |
# | fan_l |       |       | 1     | V100  | 293.8 | 293.7 | UPLOA | Jul   |
# | arge_ |       |       |       |       |       | 6 MB  | D_COM | 17,   |
# | hybri |       |       |       |       |       |       | PLETE | 2023  |
# | d_nvi |       |       |       |       |       |       |       |       |
# | magen |       |       |       |       |       |       |       |       |
# | et    |       |       |       |       |       |       |       |       |
# | fan_h |       |       |       |       |       | 26.55 | UPLOA | Jul   |
# | ybrid |       |       |       |       |       | MB    | D_COM | 14,   |
# | _tiny |       |       |       |       |       |       | PLETE | 2023  |
# | _nvim |       |       |       |       |       |       |       |       |
# | agene |       |       |       |       |       |       |       |       |
# | t     |       |       |       |       |       |       |       |       |
# | fan_b |       |       | 1     | V100  | 193.0 | 192.9 | UPLOA | Jul   |
# | ase_h |       |       |       |       |       | 6 MB  | D_COM | 17,   |
# | ybrid |       |       |       |       |       |       | PLETE | 2023  |
# | _nvim |       |       |       |       |       |       |       |       |
# | agene |       |       |       |       |       |       |       |       |
# | t     |       |       |       |       |       |       |       |       |
# +-------+-------+-------+-------+-------+-------+-------+-------+-------+

# %%
# Pull pretrained model from NGC
# !ngc registry model download-version nvidia/tao/pretrained_dino_nvimagenet:resnet50 --dest $LOCAL_PROJECT_DIR/dino/
# Out:
# Getting files to download...
# ⠋ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • 0… • Remaining: … • ? • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ╸━ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╺ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ...
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠸ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠦ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠏ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠼ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠴ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠧ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠇ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠋ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠙ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
# ⠹ ━╸ • … • Remaining: 0… • … • Elapsed: 0… • Total: 1 - Completed: 0 - Failed: 0
#        …                   …

# %%
print("Check that model is downloaded into dir.")
# !ls -l $LOCAL_PROJECT_DIR/dino/pretrained_dino_nvimagenet_vresnet50/
# Out:
# Check that model is downloaded into dir.
# total 80184
# -rw------- 1 solomon solomon 82106937  七  28 14:43 gcvit_xtiny_nvimagenet.pth

# %% [markdown]
# ## 3. Provide training specification <a class="anchor" id="head-3"></a>
#
# We provide specification files to configure the training parameters including:
#
# * dataset: configure the dataset and augmentation methods
#     * train_data_sources:
#         * image_dir: annotation file for train data. required to be in COCO json format
#         * json_file: the root directory for train images
#     * val_data_sources:
#         * image_dir: the root directory for validation images
#         * json_file: annotation file for validation data. required to be in COCO json format
#     * num_classes: number of classes of you training data
#     * batch_size: batch size for dataloader
#     * workers: number of workers to do data loading
# * model: configure the model setting
#     * pretrained_backbone_path: path to the pretrained backbone model. ResNet50, FAN-variants, and GCViT-variants are supported
#     * num_feature_levels: number of feature levels used from backbone
#     * dec_layers: number of decoder layers
#     * enc_layers: number of encoder layers
#     * num_queries: number of queries for the model
#     * num_select: number of top-k proposals to select from
#     * use_dn: flag to enable denoising during training
#     * dropout_ratio: drop out ratio
# * train: configure the training hyperparameters
#     * num_gpus: number of gpus
#     * num_nodes: number of nodes (num_nodes=1 for single node)
#     * val_interval: validation interval
#     * optim:
#         * lr_backbone: learning rate for backbone
#         * lr: learning rate for the rest of the model
#         * lr_steps: learning rate decay step milestone (MultiStep)
#     * num_epochs: number of epochs
#     * activation_checkpoint: recompute activations in the backward to save GPU memory. Default is `True`.
#     * precision: If set to fp16, the training is run on Automatic Mixed Precision (AMP)
#     * distributed_strategy: Default is `ddp`. `ddp_sharded` is also supported.
#
# * **Note that the sample spec is not meant to produce SOTA accuracy on COCO. To reproduce SOTA, you should set `num_feature_levels` as 4 to match the original params. In addition, the use of NVImageNet weight also cause a slightly lower mAP when compared with ImageNet weight.**
#
# Please refer to the TAO documentation about DINO to get all the parameters that are configurable.

# %%
# !cat $HOST_SPECS_DIR/train.yaml
# Out:
# train:
#   num_gpus: 1
#   num_nodes: 1
#   validation_interval: 1
#   optim:
#     lr_backbone: 2e-05
#     lr: 2e-4
#     lr_steps: [11]
#     momentum: 0.9
#   num_epochs: 5
# dataset:
#   train_data_sources:
#     - image_dir: /data/raw-data/train2017/
#       json_file: /data/raw-data/annotations/instances_train2017.json
#   val_data_sources:
#     - image_dir: /data/raw-data/val2017/
#       json_file: /data/raw-data/annotations/instances_val2017.json
#   num_classes: 11
#   batch_size: 4
#   workers: 8
#   augmentation:
#     fixed_padding: False
# model:
#   backbone: gcvit_xtiny
#   train_backbone: True
#   pretrained_backbone_path: /workspace/tao-experiments/dino/pretrained_dino_nvimagenet_vfan_hybrid_tiny_nvimagenet/fan_hybrid_tiny_nvimagenetv2.pth.tar
#   num_feature_levels: 4
#   dec_layers: 6
#   enc_layers: 6
#   num_queries: 300
#   num_select: 100
#   dropout_ratio: 0.0
#   dim_feedforward: 2048

# %% [markdown]
# ## 4. Run TAO training <a class="anchor" id="head-4"></a>
# * Provide the sample spec file and the output directory location for models
# * Evaluation uses COCO metrics. For more info, please refer to: https://cocodataset.org/#detection-eval
# * *WARNING*: [according to the orirginal paper](https://arxiv.org/abs/2203.03605), COCO training was conducted using 8 A100 gpus. As a result, **we highly recommend that you run training with multiple high-end gpus (e.g. V100, A100)**
# * COCO per-epoch training time on a single GPU (the hours may vary depending on the data location, network speed, and etc).
#
# <table>
#   <tr>
#     <th>GPU Type</th>
#     <th>Time (hrs)</th>
#   </tr>
#   <tr>
#     <td>1 x V100 32GB</td>
#     <td>21.5</td>
#   </tr>
#   <tr>
#     <td>1 x A100 80GB</td>
#     <td>8</td>
#   </tr>
# </table>
#
# * For this demonstration, we changed the architectures from the original implementation so that the training can be completed faster (e.g. num_queries 900 -> 300, num_feature_levels 4 -> 2, and etc).
# * Unlike the [original DINO paper](https://arxiv.org/abs/2203.03605), we used more advanced backbone called [FAN](https://arxiv.org/abs/2204.12451) that has proven to achieve higher downstream results compared to ResNet, Swin, and ConvNext.
# * If you wish to speed up training, you may try to set `train.precision=fp16` for mixed precision training

# %%
# NOTE: The following paths are set from the perspective of the TAO Docker.

# The data is saved here
# %env DATA_DIR = /data
# %env SPECS_DIR = /specs
# %env RESULTS_DIR = /results
# Out:
# env: DATA_DIR=/data
# env: SPECS_DIR=/specs
# env: RESULTS_DIR=/results

# %%
# !echo $HOST_DATA_DIR
# Out:
# /home/solomon/tao-experiments/data

# %%
print("For multi-GPU, change num_gpus in train.yaml based on your machine or pass --gpus to the cli.")
print("For multi-node, change num_gpus and num_nodes in train.yaml based on your machine or pass --num_nodes to the cli.")
# If you face out of memory issue, you may reduce the batch size in the spec file by passing dataset.batch_size=2
# !tao model dino train \
          -e $SPECS_DIR/train.yaml \
          results_dir=$RESULTS_DIR/
# Out:
# For multi-GPU, change num_gpus in train.yaml based on your machine or pass --gpus to the cli.
# For multi-node, change num_gpus and num_nodes in train.yaml based on your machine or pass --num_nodes to the cli.
# 2023-07-28 14:48:13,506 [TAO Toolkit] [INFO] root 160: Registry: ['nvcr.io']
# 2023-07-28 14:48:13,596 [TAO Toolkit] [INFO] nvidia_tao_cli.components.instance_handler.local_instance 360: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:5.0.0-pyt
# 2023-07-28 14:48:13,650 [TAO Toolkit] [INFO] nvidia_tao_cli.components.docker_handler.docker_handler 275: Printing tty value True
# INFO: generated new fontManager
# INFO: Generating grammar tables from /usr/lib/python3.8/lib2to3/Grammar.txt
# INFO: Generating grammar tables from /usr/lib/python3.8/lib2to3/PatternGrammar.txt
# /usr/local/lib/python3.8/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# INFO: Generating grammar tables from /usr/lib/python3.8/lib2to3/Grammar.txt
# INFO: Generating grammar tables from /usr/lib/python3.8/lib2to3/PatternGrammar.txt
# /usr/local/lib/python3.8/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# sys:1: UserWarning:
# 'train.yaml' is validated against ConfigStore schema with the same name.
# This behavior is deprecated in Hydra 1.1 and will be removed in Hydra 1.2.
# See https://hydra.cc/docs/next/upgrades/1.0_to_1.1/automatic_schema_matching for migration instructions.
# <frozen core.hydra.hydra_runner>:107: UserWarning:
# 'train.yaml' is validated against ConfigStore schema with the same name.
# This behavior is deprecated in Hydra 1.1 and will be removed in Hydra 1.2.
# See https://hydra.cc/docs/next/upgrades/1.0_to_1.1/automatic_schema_matching for migration instructions.
# /usr/local/lib/python3.8/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/next/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# Train results will be saved at: /results/train
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3435.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Loaded pretrained weights from /workspace/tao-experiments/dino/pretrained_dino_nvimagenet_vgcvit_xtiny_nvimagenet/gcvit_xtiny_nvimagenet.pth
# _IncompatibleKeys(missing_keys=['norm1.weight', 'norm1.bias', 'norm2.weight', 'norm2.bias', 'norm3.weight', 'norm3.bias'], unexpected_keys=['norm.weight', 'norm.bias', 'head.fc.weight', 'head.fc.bias'])
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: /results/train/lightning_logs
# Serializing 0 elements to byte tensors and concatenating them all ...
# need at least one array to concatenate
# Error executing job with overrides: ['results_dir=/results/']
# An error occurred during Hydra's exception formatting:
# AssertionError()
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/hydra/_internal/utils.py", line 254, in run_and_report
#     assert mdl is not None
# AssertionError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "</usr/local/lib/python3.8/dist-packages/nvidia_tao_pytorch/cv/dino/scripts/train.py>", line 3, in <module>
#   File "<frozen cv.dino.scripts.train>", line 209, in <module>
#   File "<frozen core.hydra.hydra_runner>", line 107, in wrapper
#   File "/usr/local/lib/python3.8/dist-packages/hydra/_internal/utils.py", line 389, in _run_hydra
#     _run_app(
#   File "/usr/local/lib/python3.8/dist-packages/hydra/_internal/utils.py", line 452, in _run_app
#     run_and_report(
#   File "/usr/local/lib/python3.8/dist-packages/hydra/_internal/utils.py", line 296, in run_and_report
#     raise ex
#   File "/usr/local/lib/python3.8/dist-packages/hydra/_internal/utils.py", line 213, in run_and_report
#     return func()
#   File "/usr/local/lib/python3.8/dist-packages/hydra/_internal/utils.py", line 453, in <lambda>
#     lambda: hydra.run(
#   File "/usr/local/lib/python3.8/dist-packages/hydra/_internal/hydra.py", line 132, in run
#     _ = ret.return_value
#   File "/usr/local/lib/python3.8/dist-packages/hydra/core/utils.py", line 260, in return_value
#     raise self._return_value
#   File "/usr/local/lib/python3.8/dist-packages/hydra/core/utils.py", line 186, in run_job
#     ret.return_value = task_function(task_cfg)
#   File "<frozen cv.dino.scripts.train>", line 205, in main
#   File "<frozen cv.dino.scripts.train>", line 194, in main
#   File "<frozen cv.dino.scripts.train>", line 172, in run_experiment
#   File "/usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/trainer.py", line 603, in fit
#     call._call_and_handle_interrupt(
#   File "/usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/call.py", line 38, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/trainer.py", line 645, in _fit_impl
#     self._run(model, ckpt_path=self.ckpt_path)
#   File "/usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/trainer.py", line 1037, in _run
#     self._call_setup_hook()  # allow user to setup lightning_module in accelerator environment
#   File "/usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/trainer.py", line 1284, in _call_setup_hook
#     self._call_lightning_datamodule_hook("setup", stage=fn)
#   File "/usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/trainer.py", line 1361, in _call_lightning_datamodule_hook
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/nvidia_tao_pytorch/cv/deformable_detr/dataloader/od_data_module.py", line 64, in setup
#     self.train_dataset = build_shm_dataset(train_data_sources, train_transform)
#   File "/usr/local/lib/python3.8/dist-packages/nvidia_tao_pytorch/cv/deformable_detr/dataloader/serialized_dataset.py", line 117, in build_shm_dataset
#     dataset = SerializedDatasetFromList(dataset_list, transforms=transforms)
#   File "/usr/local/lib/python3.8/dist-packages/nvidia_tao_pytorch/cv/deformable_detr/dataloader/serialized_dataset.py", line 146, in __init__
#     self._lst = np.concatenate(self._lst)
#   File "<__array_function__ internals>", line 180, in concatenate
# ValueError: need at least one array to concatenate
# Execution status: FAIL
# 2023-07-28 14:48:34,719 [TAO Toolkit] [INFO] nvidia_tao_cli.components.docker_handler.docker_handler 337: Stopping container.

# %%
print('Trained checkpoints:')
print('---------------------')
# !ls -ltrh $HOST_RESULTS_DIR/train

# %%
# You can set NUM_EPOCH to the epoch corresponding to any saved checkpoint
# %env NUM_EPOCH=11

# %%
# Get the name of the checkpoint corresponding to your set epoch
tmp=!ls $HOST_RESULTS_DIR/train/*.pth | grep epoch=$NUM_EPOCH
# %env CHECKPOINT={tmp[0]}

print('Rename a trained model: ')
print('---------------------')
# !cp $CHECKPOINT $HOST_RESULTS_DIR/train/dino_model.pth
# !ls -ltrh $HOST_RESULTS_DIR/train/dino_model.pth

# %% [markdown]
# ## 5. Evaluate a trained model <a class="anchor" id="head-5"></a>
#
# In this section, we run the `evaluate` tool to evaluate the trained model and produce the mAP metric.
#
# We provide evaluate.yaml specification files to configure the evaluate parameters including:
#
# * model: configure the model setting
#     * this config should remain same as your trained model's configuration.
# * dataset: configure the dataset and augmentation methods
#     * test_data_sources:
#         * image_dir: the root directory for evaluatation images
#         * json_file: annotation file for evaluatation data. required to be in COCO json format.
#     * num_classes: number of classes you used for training
#     * eval_class_ids: classes you would like to evaluate. \
#                     Note that current config file will evaluate only on class 1 (person in COCO dataset)\
#                     If you remove this from config file, it will evaluate and compute the average over entire classes.
#     * batch_size
#     * workers
# * evaluate:
#     * num_gpus: number of gpus
#     * conf_threshold: a threshold for confidence scores
#
# * **NOTE: You need to change the model path in evaluate.yaml file based on your setting.**

# %%
# Evaluate on TAO model
# !tao model dino evaluate \
            -e $SPECS_DIR/evaluate.yaml \
            evaluate.checkpoint=$RESULTS_DIR/train/dino_model.pth \
            results_dir=$RESULTS_DIR/

# %% [markdown]
# ## 6. Visualize Inferences <a class="anchor" id="head-6"></a>
# In this section, we run the `inference` tool to generate inferences on the trained models and visualize the results. The `inference` tool produces annotated image outputs and txt files that contain prediction information.
#
# We provide evaluate.yaml specification files to configure the evaluate parameters including:
#
# * model: configure the model setting
#     * this config should remain same as your trained model's configuration
# * dataset: configure the dataset and augmentation methods
#     * infer_data_sources:
#         * image_dir: the list of directories for inference images
#         * classmap:
#     * num_classes: number of classes you used for training
#     * batch_size
#     * workers
# * inference
#     * conf_threshold: the confidence score threshold
#     * color_map: the color mapping for each class. The predicted bbox will be drawn with mapped color for each class
# * **NOTE: You need to change the model path in infer.yaml file based on your setting.**

# %%
# copy classmap to annotation directory
# !cp $HOST_SPECS_DIR/classmap.txt $HOST_DATA_DIR/raw-data/annotations/

# %%
# !tao model dino inference \
        -e $SPECS_DIR/infer.yaml \
        inference.checkpoint=$RESULTS_DIR/train/dino_model.pth \
        results_dir=$RESULTS_DIR/

# %%
# Simple grid visualizer
# !pip3 install matplotlib==3.3.3
import matplotlib.pyplot as plt
import os
from math import ceil
valid_image_ext = ['.jpg']

def visualize_images(output_path, num_cols=4, num_images=10):
    num_rows = int(ceil(float(num_images) / float(num_cols)))
    f, axarr = plt.subplots(num_rows, num_cols, figsize=[80,30])
    f.tight_layout()
    a = [os.path.join(output_path, image) for image in os.listdir(output_path) 
         if os.path.splitext(image)[1].lower() in valid_image_ext]
    for idx, img_path in enumerate(a[:num_images]):
        col_id = idx % num_cols
        row_id = idx // num_cols
        img = plt.imread(img_path)
        axarr[row_id, col_id].imshow(img)

# %%
# Visualizing the sample images.
IMAGE_DIR = os.path.join(os.environ['HOST_RESULTS_DIR'], "inference", "images_annotated")
COLS = 2 # number of columns in the visualizer grid.
IMAGES = 4 # number of images to visualize.

visualize_images(IMAGE_DIR, num_cols=COLS, num_images=IMAGES)

# %% [markdown]
# ## 7. Deploy <a class="anchor" id="head-7"></a>

# %%
# Export the RGB model to ONNX model
# !tao model dino export \
           -e $SPECS_DIR/export.yaml \
           export.checkpoint=$RESULTS_DIR/train/dino_model.pth \
           export.onnx_file=$RESULTS_DIR/export/dino_model.onnx \
           results_dir=$RESULTS_DIR/

# %%
# Generate TensorRT engine using tao deploy
# !tao deploy dino gen_trt_engine -e $SPECS_DIR/gen_trt_engine.yaml \
                               gen_trt_engine.onnx_file=$RESULTS_DIR/export/dino_model.onnx \
                               gen_trt_engine.trt_engine=$RESULTS_DIR/gen_trt_engine/dino_model.engine \
                               results_dir=$RESULTS_DIR

# %%
# Evaluate with generated TensorRT engine
# !tao deploy dino evaluate -e $SPECS_DIR/evaluate.yaml \
                              evaluate.trt_engine=$RESULTS_DIR/gen_trt_engine/dino_model.engine \
                              results_dir=$RESULTS_DIR/

# %%
# Inference with generated TensorRT engine
# !tao deploy dino inference -e $SPECS_DIR/infer.yaml \
                              inference.trt_engine=$RESULTS_DIR/gen_trt_engine/dino_model.engine \
                              results_dir=$RESULTS_DIR/

# %%
# Visualizing the sample images.
IMAGE_DIR = os.path.join(os.environ['HOST_RESULTS_DIR'], "trt_inference", "images_annotated")
COLS = 2 # number of columns in the visualizer grid.
IMAGES = 4 # number of images to visualize.

visualize_images(IMAGE_DIR, num_cols=COLS, num_images=IMAGES)

# %% [markdown]
# This notebook has come to an end.
